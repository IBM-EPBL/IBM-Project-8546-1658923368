# %% [markdown]
# <a href="https://colab.research.google.com/github/IBM-EPBL/IBM-Project-8546-1658923368/blob/main/Assignment/Sukirdha%20Priya_T_IBM_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello world

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# Find square root

# %%
num = 8 
num_sqrt = num ** 0.5
print('The square root of %0.3f is %0.3f'%(num ,num_sqrt))
# Out:
# The square root of 8.000 is 2.828

# %% [markdown]
# Area of triangle

# %%
a = 5
b = 6
c = 7
s = (a + b + c) / 2
area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
print('The area of the triangle is %0.2f' %area)
# Out:
# The area of the triangle is 14.70

# %% [markdown]
# Swap two variables

# %%
x = 5
y = 10
temp = x
x = y
y = temp

print('The value of x after swapping: {}'.format(x))
print('The value of y after swapping: {}'.format(y))
# Out:
# The value of x after swapping: 10
# The value of y after swapping: 5

# %% [markdown]
# operators

# %%
x = 15
y = 4

# Output: x + y = 19
print('x + y =',x+y)

# Output: x - y = 11
print('x - y =',x-y)

# Output: x * y = 60
print('x * y =',x*y)

# Output: x / y = 3.75
print('x / y =',x/y)

# Output: x // y = 3
print('x // y =',x//y)

# Output: x ** y = 50625
print('x ** y =',x**y)
# Out:
# x + y = 19
# x - y = 11
# x * y = 60
# x / y = 3.75
# x // y = 3
# x ** y = 50625

# %%
if...else

# %%
num = 3
if num > 0:
    print(num, "is a positive number.")
print("This is always printed.")

num = -1
if num > 0:
    print(num, "is a positive number.")
print("This is also always printed.")
# Out:
# 3 is a positive number.
# This is always printed.
# This is also always printed.

# %% [markdown]
# for loop

# %%
numbers = [6, 5, 3, 8, 4, 2, 5, 4, 11]
sum = 0
for val in numbers:
    sum = sum+val

print("The sum is", sum)
# Out:
# The sum is 48

# %% [markdown]
# while loop

# %%
n = 10
sum = 0
i = 1

while i <= n:
    sum = sum + i
    i = i+1    
print("The sum is", sum)
# Out:
# The sum is 55

# %% [markdown]
# Functions

# %%
def greet(name):
    print("Hello, " + name + ". Good morning!")
greet('Paul')
# Out:
# Hello, Paul. Good morning!

# %% [markdown]
# Recursion

# %%
def factorial(x):
    if x == 1:
        return 1
    else:
        return (x * factorial(x-1))
num = 3
print("The factorial of", num, "is", factorial(num))
# Out:
# The factorial of 3 is 6

# %% [markdown]
# list

# %%
my_list = ['p','r','o','b','e']

# last item
print(my_list[-1])

# fifth last item
print(my_list[-5])
# Out:
# e
# p

# %% [markdown]
# Tuple

# %%
my_tuple = ()
my_tuple = ("mouse", [8, 4, 6], (1, 2, 3))
print(my_tuple)
# Out:
# ('mouse', [8, 4, 6], (1, 2, 3))

# %% [markdown]
# String

# %%
str = 'programiz'
print('str[0] = ', str[0])
print('str[1:5] = ', str[1:5])
print('str[5:-2] = ', str[5:-2])
# Out:
# str[0] =  p
# str[1:5] =  rogr
# str[5:-2] =  am

# %% [markdown]
# Set

# %%
my_set = {1.0, "Hello", (1, 2, 3)}
print(my_set)
# Out:
# {1.0, 'Hello', (1, 2, 3)}

# %% [markdown]
# Dictionary

# %%
my_dict = {'name': 'Jack', 'age': 26}
print(my_dict['name'])
print(my_dict.get('age'))
# Out:
# Jack
# 26
